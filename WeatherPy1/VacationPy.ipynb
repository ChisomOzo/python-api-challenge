# %% [markdown]
# # VacationPy
# ---
#
# ## Starter Code to Import Libraries and Load the Weather and Coordinates Data

# %%
# Dependencies and Setup
import hvplot.pandas
import pandas as pd
import requests
import warnings
warnings.filterwarnings("ignore")

# Import API key
from api_keys import geoapify_key

# %%
# Load the CSV file created in Part 1 into a Pandas DataFrame
city_data_df = pd.read_csv("../output_data/cities.csv")

# Display sample data
city_data_df.head()
# Out:
#    City_ID         City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0        0         faya  18.3851   42.4509     22.06        35          21
# 1        1      farsund  58.0948    6.8047     13.30       100           0
# 2        2  new norfolk -42.7826  147.0587     11.72        58          12
# 3        3    jamestown  42.0970  -79.2353      5.77        77         100
# 4        4      lanzhou  36.0564  103.7922     14.53        48          59
#
#    Wind Speed Country        Date
# 0        2.60      SA  1666108228
# 1        7.65      NO  1666108228
# 2        1.34      AU  1666108230
# 3        9.77      US  1666107934
# 4        1.20      CN  1666108230

# %% [markdown]
# ---
#
# ### Step 1: Create a map that displays a point for every city in the `city_data_df` DataFrame. The size of the point should be the humidity in each city.

# %%
# %%capture --no-display

# Configure the map plot
map_plot_1 = city_data_df.hvplot.points(
    "Lng",
    "Lat",
    geo = True,
    tiles = "OSM"
)

# Display the map
map_plot_1
# Out:
# :Overlay
#    .Tiles.I  :Tiles   [x,y]
#    .Points.I :Points   [Lng,Lat]

# %% [markdown]
# ### Step 2: Narrow down the `city_data_df` DataFrame to find your ideal weather condition

# %%
# Narrow down cities that fit criteria and drop any results with null values
clean_weather= city_data_df
clean_weather= clean_weather.loc[(clean_weather['Cloudiness']==0)]
clean_weather = clean_weather.loc[(clean_weather["Max Temp"] <= 21)]
clean_weather = clean_weather.loc[(clean_weather["Wind Speed"] < 4.5)]

# Drop any rows with null values
clean_weather=clean_weather.dropna()



# Display sample data
clean_weather
# Out:
#      City_ID           City      Lat       Lng  Max Temp  Humidity  \
# 90        90   saint george  37.1041 -113.5841     13.33        44
# 96        96        zhangye  38.9342  100.4517     11.11        16
# 115      115     cedar city  37.6775 -113.0619     14.11        49
# 121      121        lichuan  30.3000  108.8500      9.72        77
# 128      128  half moon bay  37.4636 -122.4286     19.71        86
# 141      141        brenham  30.1669  -96.3977     14.47        40
# 159      159      geraldton -28.7667  114.6000     13.23        88
# 268      268        chengde  40.9725  117.9361      5.17        26
# 293      293  kamen-rybolov  44.7481  132.0403      2.69        55
# 314      314        horsham  51.0640   -0.3272     18.40        72
# 331      331     swan river  52.1058 -101.2676      0.94        40
# 367      367  saint anthony  45.0205  -93.2180      0.14        61
# 376      376        fortuna  40.5982 -124.1573     10.51       100
# ...

# %% [markdown]
# ### Step 3: Create a new DataFrame called `hotel_df`.

# %%
# Use the Pandas copy function to create DataFrame called hotel_df to store the city, country, coordinates, and humidity
hotel_df=clean_weather.drop(columns=["City_ID", "Date","Wind Speed","Cloudiness","Max Temp"])
hotel_df["Hotel Name"] = ""
# hotel_df= pd.DataFrame({"Hotel Name"})
#     "City",
#     "Country",
#     "Lat",
#     "Lng",
#     "Humidity",

# hotel_df
# Add an empty column, "Hotel Name," to the DataFrame so you can store the hotel found using the Geoapify API
# hotel_df2.loc['Hotel Name'] = ['name']

# Display sample data
hotel_df
# Out:
#               City      Lat       Lng  Humidity Country Hotel Name
# 90    saint george  37.1041 -113.5841        44      US
# 96         zhangye  38.9342  100.4517        16      CN
# 115     cedar city  37.6775 -113.0619        49      US
# 121        lichuan  30.3000  108.8500        77      CN
# 128  half moon bay  37.4636 -122.4286        86      US
# 141        brenham  30.1669  -96.3977        40      US
# 159      geraldton -28.7667  114.6000        88      AU
# 268        chengde  40.9725  117.9361        26      CN
# 293  kamen-rybolov  44.7481  132.0403        55      RU
# 314        horsham  51.0640   -0.3272        72      GB
# 331     swan river  52.1058 -101.2676        40      CA
# 367  saint anthony  45.0205  -93.2180        61      US
# 376        fortuna  40.5982 -124.1573       100      US
# 394        quesnel  52.9999 -122.5029        93      CA
# 402          seoul  37.5683  126.9778        70      KR
# 428          aktau  43.6500   51.2000        46      KZ
# ...

# %% [markdown]
# ### Step 4: For each city, use the Geoapify API to find the first hotel located within 10,000 metres of your coordinates.

# %%
# Set parameters to search for a hotel
radius = 50000
params = {
    "categories":"hotel",
    "apiKey": geoapify_key,
    "limit":20
}
# Print a message to follow up the hotel search
print("Starting hotel search")

# Iterate through the hotel_df DataFrame
for index, row in hotel_df.iterrows():
    # get latitude, longitude from the DataFrame
    lat=row["Lat"]
    lng=row["Lng"]
    
    # Add filter and bias parameters with the current city's latitude and longitude to the params dictionary
    params["filter"] = f"circle:{lng},{lat},{radius}"
    params["bias"] = f"proximity:{lng},{lat}"
    
    # Set base URL
    base_url = "https://api.geoapify.com/v2/places"


    # Make and API request using the params dictionaty
    name_address = row["City"]
    
    # Convert the API response to JSON format
    response = requests.get(base_url, params=params).json()
    # name_address = response['results']
    
    
    # Grab the first hotel from the results and store the name in the hotel_df DataFrame
    try:
        hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
    except (KeyError, IndexError):
        # If no hotel is found, set the hotel name as "No hotel found".
        hotel_df.loc[index, "Hotel Name"] = "No hotel found"
        
    # Log the search results
    print(f"{hotel_df.loc[index, 'City']} - nearest hotel: {hotel_df.loc[index, 'Hotel Name']}")

# Display sample data
hotel_df
# Out:
# Starting hotel search
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[143], line 35
#      30 # name_address = response['results']
#      31
#      32
#      33 # Grab the first hotel from the results and store the name in the hotel_df DataFrame
#      34 try:
# ---> 35     hotel_df.loc[index, "Hotel Name"] = name_address["features"][0]["properties"]["name"]
#      36 except (KeyError, IndexError):
#      37     # If no hotel is found, set the hotel name as "No hotel found".
#      38     hotel_df.loc[index, "Hotel Name"] = "No hotel found"
#
# TypeError: string indices must be integers

# %% [markdown]
# ### Step 5: Add the hotel name and the country as additional information in the hover message for each city in the map.

# %%
# %%capture --no-display
locations = hotel_df[["Lat", "Lng"]]


# Configure the map plot
map_plot_1 = hotel_df.hvplot.points(
    "longitude"
    "latitude",
    geo = True,
    tiles = "OSM"
)

# Display the map
map_plot_1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/IPython/core/formatters.py:974, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#     971     method = get_real_method(obj, self.print_method)
#     973     if method is not None:
# --> 974         return method(include=include, exclude=exclude)
#     975     return None
#     976 else:
#
# File ~/anaconda3/envs/dev/lib/python3.10/site-packages/holoviews/core/dimension.py:1287, in Dimensioned._repr_mimebundle_(self, include, exclude)
#    1280 def _repr_mimebundle_(self, include=None, exclude=None):
#    1281     """
#    1282     Resolves the class hierarchy for the class rendering the
#    1283     object using any display hooks registered on Store.display
#    1284     hooks.  The output of all registered display_hooks is then
# ...
